# %% [markdown]
# <a href="https://colab.research.google.com/github/robsonspereira/COVID19/blob/master/SEIR_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Seir Model
# <b>S</b>usceptible <br>
# <b>E</b>xposed <br>
# <b>I</b>nfected<br>
# <b>R</b>ecovered<br>
#
#
#
# 1.   α is the inverse of the incubation period (1/t_incubation)
# 2.   β is the average contact rate in the populatioN
# 3.γ is the inverse of the mean infectious period (1/t_infectious)
#
#
# https://towardsdatascience.com/social-distancing-to-slow-the-coronavirus-768292f04296

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import math

# %%
# Define parameters
t_max = 365
dt = 1
t = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 12252023
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 3
gamma = 0.072
params = alpha, beta, gamma

# %%
def base_seir_model(init_vals, params, t):
   
    S_0, E_0, I_0, R_0 = init_vals
    S, E, I, R = [S_0], [E_0], [I_0], [R_0]
    alpha, beta, gamma = params
    listbeta = [beta]
    dt = t[1] - t[0]
    for _ in t[1:]:
        next_S = S[-1] - (beta*S[-1]*I[-1])*dt
        next_E = E[-1] + (beta*S[-1]*I[-1] - alpha*E[-1])*dt
        next_I = I[-1] + (alpha*E[-1] - gamma*I[-1])*dt
        next_R = R[-1] + (gamma*I[-1])*dt
        S.append(next_S)
        E.append(next_E)
        I.append(next_I)
        R.append(next_R)
        listbeta.append(beta)
        if beta <= 0.5:
          0.5
        else:
          beta = (beta/math.exp(_/100))
        
    return np.stack([S, E, I, R,listbeta]).T

# %%
# Run simulation
results = base_seir_model(init_vals, params, t)

#plt.plot(results)
#plt.show()

# %%
df =pd.DataFrame(results)
df.columns = ['S','E','I','R','beta']
df['Ipopulation'] = df['I']*N
df['Epopulation'] = df['E']*N
#df['S']=df.S.astype('int64')
#df['E']=df.E.astype('int64')
#df['I']=df.I.astype('int64')
#df['R']=df.R.astype('int64')

df.loc[27]
# Out:
# S                 0.999812
# E                 0.000089
# I                 0.000073
# R                 0.000026
# beta              0.448706
# Ipopulation     895.609179
# Epopulation    1085.617753
# Name: 27, dtype: float64

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(y=df['S'], name = 'Susceptible'))
fig.add_trace(go.Scatter(y=df['E'], name = 'Exposed'))
fig.add_trace(go.Scatter(y=df['I'], name = 'Infected'))
fig.add_trace(go.Scatter(y=df['R'], name = 'Recoverd'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c25250b9-2cad-4d73-8691-fbdfea82d560" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c25250b9-2cad-4d73-8691-fbdfea82d560")) {
#                     Plotly.newPlot(
#                         'c25250b9-2cad-4d73-8691-fbdfea82d560',
#                         [{"name": "Susceptible", "type": "scatter", "y": [0.9999999183808258, 0.9999999183808258, 0.9999998698965998, 0.9999997877748312, 0.999999656905169, 0.9999994518909415, 0.9999991361151777, 0.9999986588710991, 0.9999979526057318, 0.9999969311877398, 0.9999954902506594, 0.9999935107632859, 0.999990866793802, 0.9999874378389186, 0.9999831250722766, 0.9999778695884082, 0.999971669525425, 0.9999645922946758, 0.9999567784240206, 0.9999484348737911, 0.9999398178694487, 0.999929301405481, 0.9999167530430881, 0.9999019333065162, 0.999884514836218, 0.9998640882746523, 0.9998401599387782, 0.9998121439599537, 0.9997793502252283, 0.999740968675999, 0.999696050054723, 0.9996434828943808, 0.9995819663378734, 0.9995099782095725, 0.9994257376121928, 0.9993271611730562, 0.9992118119045285, 0.9990768394669453, 0.998918910423399, 0.9987341268498915, 0.9985179314076715, 0.998264996693546, 0.9979690963555665, 0.9976229550934791, 0.9972180742546276, 0.9967445292875137, 0.9961907348307335, 0.9955431727027402, 0.9947860775323