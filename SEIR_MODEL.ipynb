# %% [markdown]
# <a href="https://colab.research.google.com/github/robsonspereira/COVID19/blob/master/SEIR_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Seir Model
# <b>S</b>usceptible <br>
# <b>E</b>xposed <br>
# <b>I</b>nfected<br>
# <b>R</b>ecovered<br>
#
#
#
# 1.   α is the inverse of the incubation period (1/t_incubation)
# 2.   β is the average contact rate in the populatioN
# 3.γ is the inverse of the mean infectious period (1/t_infectious)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
def base_seir_model(init_vals, params, t):
    S_0, E_0, I_0, R_0 = init_vals
    S, E, I, R = [S_0], [E_0], [I_0], [R_0]
    alpha, beta, gamma = params
    dt = t[1] - t[0]
    for _ in t[1:]:
        next_S = S[-1] - (beta*S[-1]*I[-1])*dt
        next_E = E[-1] + (beta*S[-1]*I[-1] - alpha*E[-1])*dt
        next_I = I[-1] + (alpha*E[-1] - gamma*I[-1])*dt
        next_R = R[-1] + (gamma*I[-1])*dt
        S.append(next_S)
        E.append(next_E)
        I.append(next_I)
        R.append(next_R)
    return np.stack([S, E, I, R]).T

# %%
# Define parameters
t_max = 365
dt = 1
t = np.linspace(0, t_max, int(t_max/dt) + 1)
N = 12252023
init_vals = 1 - 1/N, 1/N, 0, 0
alpha = 0.2
beta = 0.5
gamma = 0.1
params = alpha, beta, gamma
# Run simulation
results = base_seir_model(init_vals, params, t)

#plt.plot(results)
#plt.show()

# %%
df =pd.DataFrame(results)
df.columns = ['S', 'E','I','R']
df['Ipopulation'] = df['I']*N
df['Epopulation'] = df['E']*N
#df['S']=df.S.astype('int64')
#df['E']=df.E.astype('int64')
#df['I']=df.I.astype('int64')
#df['R']=df.R.astype('int64')

df
# Out:
#             S             E  ...  Ipopulation  Epopulation
# 0    1.000000  8.161917e-08  ...     0.000000     1.000000
# 1    1.000000  6.529534e-08  ...     0.200000     0.800000
# 2    1.000000  6.039819e-08  ...     0.340000     0.740000
# 3    1.000000  6.219381e-08  ...     0.454000     0.762000
# 4    1.000000  6.828260e-08  ...     0.561000     0.836600
# ..        ...           ...  ...          ...          ...
# 361  0.005197  4.369044e-13  ...     0.000216     0.000005
# 362  0.005197  3.953776e-13  ...     0.000196     0.000005
# 363  0.005197  3.577978e-13  ...     0.000177     0.000004
# 364  0.005197  3.237899e-13  ...     0.000160     0.000004
# 365  0.005197  2.930143e-13  ...     0.000145     0.000004
#
# [366 rows x 6 columns]

# %%
fig = go.Figure()
#fig.add_trace(go.Scatter(y=df['S']))
fig.add_trace(go.Scatter(y=df['Epopulation']))
fig.add_trace(go.Scatter(y=df['Ipopulation']))
#fig.add_trace(go.Scatter(y=df['R']))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d8009fcf-c266-4643-aa7b-1f22da88c3e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d8009fcf-c266-4643-aa7b-1f22da88c3e6")) {
#                     Plotly.newPlot(
#                         'd8009fcf-c266-4643-aa7b-1f22da88c3e6',
#                         [{"type": "scatter", "y": [1.0, 0.7999999999999999, 0.7399999918380825, 0.7619999782076806, 0.8365999582199616, 0.9497799293895811, 1.0959338879490461, 1.274224028608621, 1.4867018040394122, 1.7373741221115042, 2.031780824233793, 2.376855356115231, 2.7809498713083554, 3.2539642911137885, 3.8075501418814435, 4.4553770608166605, 5.21345947608677, 6.1005467285298645, 7.138583735698664, 8.353252243639227, 9.77460534096668, 11.4378105536226, 13.384019703033688, 15.66138694047823, 18.326260085571917, 21